# %% [markdown]
# https://huggingface.co/learn/nlp-course/chapter1/1

# %%
# !wget q --show-progress --no-check-certificate 'https://docs.google.com/uc?export=download&id=14zQMn9e1E60ZkA1-N674TDv1bkV6wyYo' -O 'np-cov-10k.csv'
# Out:
# --2023-12-01 10:08:06--  http://q/
# Resolving q (q)... failed: Name or service not known.
# wget: unable to resolve host address ‘q’
# --2023-12-01 10:08:06--  https://docs.google.com/uc?export=download&id=14zQMn9e1E60ZkA1-N674TDv1bkV6wyYo
# Resolving docs.google.com (docs.google.com)... 142.250.152.138, 142.250.152.101, 142.250.152.113, ...
# Connecting to docs.google.com (docs.google.com)|142.250.152.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0g-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/iv7u6h507i55t8f5smjktg1lq4kqeurr/1701425250000/15645107078338217022/*/14zQMn9e1E60ZkA1-N674TDv1bkV6wyYo?e=download&uuid=a8294292-48df-4ed3-9586-3f7c9d866a60 [following]
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# ...

# %%
#Imports
import transformers
import pandas as pd
import datasets
import torch
import numpy as np

# %%
#--------Préparation du dataset--------#
df = pd.read_csv("np-cov-10k.csv")
dataset = datasets.Dataset.from_pandas(df)

data = dataset.train_test_split(test_size=0.05)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8d6f2d81adbd> in <cell line: 2>()
#       1 #--------Préparation du dataset--------#
# ----> 2 df = pd.read_csv("/content/mydf.csv")
#       3 dataset = datasets.Dataset.from_pandas(df)
#       4
#       5 data = dataset.train_test_split(test_size=0.05)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
#--------Charger les outils préentrainés--------#
from transformers import XLMRobertaForSequenceClassification, XLMRobertaTokenizer

# model = XLMRobertaForSequenceClassification.from_pretrained('xlm-roberta-base', num_labels=6)
# tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')

#ou
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("launch/POLITICS")
model = AutoModelForMaskedLM.from_pretrained("launch/POLITICS")

# Je pense que le AutoModelForSequenceClassification est mieux adapté pour pour prédire des catégories ou des étiquettes associées à des textes politiques.

# %%
#--------Prétraitement_données--------#

train_data = data["train"]
test_data = data["test"]

##Il faut tokenizer la mais je suis pas encore 100% sur de l'avoir fait correctement

# %%
#--------Trainnig--------#
from transformers import TrainingArguments, Trainer

# %%
#--------Evaluation-------#
